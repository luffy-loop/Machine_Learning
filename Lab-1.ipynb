# %% [markdown]
# <a href="https://colab.research.google.com/github/luffy-loop/Machine_Learning/blob/main/Lab-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib
import sklearn

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-296449cf-ee07-49e9-946f-7c577647ad41" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-296449cf-ee07-49e9-946f-7c577647ad41">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Load Dataset
import pandas as pd
df = pd.read_csv("lab-1-student_placement_prediction_dataset.csv")
print(df.head())
# Out:
#    student_id  age gender  cgpa branch college_tier  internships_count  \
# 0           1   24    NaN  7.53     IT       Tier 2                  4
# 1           2   21    NaN  7.92    CSE       Tier 2                  1
# 2           3   22    NaN  8.60    EEE       Tier 1                  0
# 3           4   24    NaN  6.68    CSE       Tier 1                  0
# 4           5   20    NaN  8.43     IT       Tier 3                  1
#
#    projects_count  certifications_count  coding_skill_score  ...  \
# 0               6                     1           99.238568  ...
# 1               3                     6           80.966123  ...
# 2               1                     1           49.177184  ...
# 3               2                     2           79.359084  ...
# 4               4                     3           65.018573  ...
#
#    mock_interview_score  attendance_percentage  backlogs  \
# 0             72.647009              77.463863         2
# ...

# %%
# Basic Dataset Inspection


print("Dataset Shape")

print(df.shape)
print("=" * 60)
print("Data Types")
print(df.dtypes)
# Out:
# Dataset Shape
# (100000, 26)
# ...
# Data Types
# student_id                     int64
# age                            int64
# gender                        object
# cgpa                         float64
# branch                        object
# college_tier                  object
# internships_count              int64
# projects_count                 int64
# certifications_count           int64
# coding_skill_score           float64
# aptitude_score               float64
# communication_skill_score    float64
# logical_reasoning_score      float64
# hackathons_participated        int64
# github_repos                   int64
# linkedin_connections           int64
# mock_interview_score         float64
# attendance_percentage        float64
# backlogs                       int64
# extracurricular_score        float64
# leadership_score             float64
# volunteer_experience          object
# sleep_hours                  float64
# study_hours_per_day          float64
# ...

# %%
print("Statistical Summary")
print("=" * 60)
print(df.describe(include='all'))
# Out:
# Statistical Summary
# ...
#            student_id            age gender           cgpa  branch  \
# count   100000.000000  100000.000000  99994  100000.000000  100000
# unique            NaN            NaN      2            NaN       6
# top               NaN            NaN   Male            NaN     CSE
# freq              NaN            NaN  60024            NaN   34818
# mean     50000.500000      21.005740    NaN       7.496890     NaN
# std      28867.657797       1.999562    NaN       0.992834     NaN
# min          1.000000      18.000000    NaN       4.500000     NaN
# 25%      25000.750000      19.000000    NaN       6.820000     NaN
# 50%      50000.500000      21.000000    NaN       7.500000     NaN
# 75%      75000.250000      23.000000    NaN       8.180000     NaN
# max     100000.000000      24.000000    NaN      10.000000     NaN
#
#        college_tier  internships_count  projects_count  certifications_count  \
# ...
