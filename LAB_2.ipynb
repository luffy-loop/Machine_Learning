# %% [markdown]
# <a href="https://colab.research.google.com/github/luffy-loop/Machine_Learning/blob/main/LAB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create the input data (X)
# There are 5 data points (N = 5)
# Each point has 2 input features (L = 2)
X = np.array([[1,2],
              [2,1],
              [3,4],
              [4,3],
              [5,5]])

# %%
#Create the output values (Target)
# There is one output for each input (M = 1)
y = np.array([5, 6, 9, 10, 13])

# %%
# Add the bias (intercept) term
# np.ones(len(X)) creates a column of ones
# np.c_ joins this column with X
# New X becomes:
# [[1,1,2],
#  [1,2,1],
#  [1,3,4],
#  [1,4,3],
#  [1,5,5]]
# First column = Bias term
X = np.c_[np.ones(len(X)), X]
